# %% [markdown]
# ## This Data is about Company Logistic System in America (Data From Kaggle)

# %% [markdown]
# <font size = 6>
# <div class = 'alert alert-block alert-warning'>
#     <strong>Data Preparation</strong>
#     </div>
#     </font>

# %%
#Import Library and tools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Import Data</strong>
#     </div>
#     </font>

# %%
df = pd.read_csv('SampleSuperstore.csv') #import Data
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Check for null</strong>
#     </div>
#     </font>

# %%
df.isnull().sum() # Check for missing Data and with the results there are no Null Data
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Check Data Type</strong>
#     </div>
#     </font>

# %%
df.info() #Check the data type that is suitable for analysis
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# <font size = 6>
# <div class = 'alert alert-block alert-warning'>
#     <strong>Data Analysis</strong>
#     </div>
#     </font>

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Which State has the most Profit</strong>
#     </div>
#     </font>

# %%
df.groupby(by = 'State').sum().sort_values(by = 'Sales',ascending = False).head()['Sales'] #Group and sort data
# Out:
# State
# California      457687.6315
# New York        310876.2710
# Texas           170188.0458
# Washington      138641.2700
# Pennsylvania    116511.9140
# Name: Sales, dtype: float64

# %%
df.groupby(by = 'State').sum().sort_values(by = 'Profit',ascending = False).head()['Profit'] #Group and sort data
# Out:
# State
# California    76380.4163
# New York      74038.5486
# Washington    33402.6517
# Michigan      24461.1876
# Virginia      18597.9504
# Name: Profit, dtype: float64

# %% [markdown]
# ## From the table above,we see that California has the highest Profit and Sales at 457,687 dollars

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Are there any State that is loss</strong>
#     </div>
#     </font>

# %%
df = pd.read_csv('SampleSuperstore.csv') #import Data

# %%
df = df.groupby(by = 'State').sum() #Group data

# %%
df[df['Profit'] <= 0].sort_values(by = 'Profit',ascending = True) #set the data to show only the columns that has profit less than or equal to 0
# Out:
#                 Postal Code        Sales  Quantity  Discount      Profit
# State
# Texas              75747693  170188.0458      3724    364.64 -25729.3563
# Ohio               20579836   78258.1360      1759    152.40 -16971.3766
# Pennsylvania       11190565  116511.9140      2153    192.90 -15559.9603
# Illinois           29873772   80166.1010      1845    191.90 -12607.8870
# North Carolina      6994384   55603.1640       983     70.60  -7490.9122
# Colorado           14613828   32108.1180       693     57.60  -6527.8579
# Tennessee           6890574   30661.8730       681     53.30  -5341.6936
# Arizona            19102126   35282.0010       862     68.00  -3427.9246
# Florida            12640225   89473.7080      1379    114.65  -3399.3017
# Oregon             12072125   17431.1500       499     35.80  -1190.4705

# %% [markdown]
# ## From the result, there are 10 States that doesn't make any profit and Texas has the most loss at 25,729 dollars

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>สาเหตุ?</strong>
#     </div>
#     </font>

# %%
df = pd.read_csv('SampleSuperStore.csv') #import file

# %%
df.drop(columns = 'Postal Code',inplace = True) #drop Postal Code

# %%
sns.heatmap(df.corr(),annot = True) #look at the correlation of the data
# Out:
# <AxesSubplot:>

# %%
df[df['State'] == 'Texas'].sort_values(by = 'Profit')[['Sub-Category','Profit']]
# Out:
#      Sub-Category     Profit
# 9774      Binders -3701.8928
# 5310      Binders -2287.7820
# 1199      Binders -1850.9464
# 3324      Binders -1480.0335
# 165      Machines -1359.9920
# ...           ...        ...
# 2516    Envelopes   204.0714
# 4861       Phones   265.4232
# 281        Phones   376.1100
# 7173      Copiers   569.9905
# 5756      Copiers   624.9875
#
# [985 rows x 2 columns]

# %% [markdown]
# ## From the picture above, we see that discount has a little effect on quantity sales(at 0.0086) combine with the information above .You will see that Texas which has a higher discount than California is not working . another reason is that Texas is selling Product that isn't make any money.According to the table above, Binder is a product which doesn't make any profit so to fix this situation the Sales team need to change the product price or drop out this product.

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong> Which Region has the highest Sales and Profit ? </strong>
#     </div>
#     </font>

# %%
df = pd.read_csv('SampleSuperStore.csv') # import data
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.groupby(by = 'Region').sum().sort_values(by = 'Sales',ascending = False) #group data using Region as a condition
# Out:
#          Postal Code        Sales  Quantity  Discount       Profit
# Region
# West       293739752  725457.8245     12266    350.20  108417.4781
# East        50171698  678781.2400     10618    414.00   91522.7800
# Central    151786150  501239.8908      8780    558.34   39704.3625
# South       55875052  391720.9050      6209    238.55   46749.4303

# %% [markdown]
# ## From the table above we see that  West is a region which has the most Sales at 725,457 dollars and Profit rate at 108,417 dollars.

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Sales Trend</strong>
#     </div>
#     </font>

# %%
sns.jointplot(x = 'Sales',y = 'Profit',data = df,kind = 'reg')

# %% [markdown]
# ## From the graph you see that both when Sales and Profit values is correlate to each other but according to grah,you see that there are some Sales that is a loss

# %%
df[['Category','Sub-Category','Profit','Sales']].sort_values(by = 'Profit',ascending = True) #look which product has the highest loss
# Out:
#              Category Sub-Category     Profit      Sales
# 7772       Technology     Machines -6599.9780   4499.985
# 683        Technology     Machines -3839.9904   7999.980
# 9774  Office Supplies      Binders -3701.8928   2177.584
# 3011       Technology     Machines -3399.9800   2549.985
# 4991  Office Supplies      Binders -2929.4845   1889.990
# ...               ...          ...        ...        ...
# 4098  Office Supplies      Binders  4630.4755   9449.950
# 9039  Office Supplies      Binders  4946.3700   9892.740
# 4190       Technology      Copiers  5039.9856  10499.970
# 8153       Technology      Copiers  6719.9808  13999.960
# 6826       Technology      Copiers  8399.9760  17499.950
#
# [9994 rows x 4 columns]

# %%
graph_data = df[df['Profit']  <= 0].groupby(by = 'Category').sum()[['Sales','Profit']] #Look at all of the product in each category that has a profit less than or equal to negative
graph_data.reset_index(inplace = True)

# %%
sns.barplot(x = 'Category',y = 'Profit',data = graph_data)
plt.ylim(reversed(plt.ylim()))
# Out:
# (0.0, -63982.914450000026)

# %% [markdown]
# ## This table is showing that every product Category has a product that has didn't make a profit at all ,this showing that Sales and Marketing teamneed to fix this issues and strategies

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Which product has the highest Sales</strong>
#     </div>
#     </font>

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# ## According to the information, Office Supplies has the highest Sales at 6026 Orders

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Which product has the highest Sales on West region</strong>
#     </div>
#     </font>

# %%
df = pd.read_csv('SampleSuperStore.csv') #import file
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df[df['Region'] == 'West']['Category'].value_counts()
#Select and Filter Data
# Out:
# Office Supplies    1897
# Furniture           707
# Technology          599
# Name: Category, dtype: int64

# %% [markdown]
# ## According to the information, Office Supplies has the highest Sales in West Region at 1,897 Orders

# %%
df[(df['Region'] == 'West') & (df['Category'] == 'Office Supplies')]['Sales'].sum()
#Sum all the Sales of the Office Supplies Product
# Out:
# 220853.249

# %% [markdown]
# ## According to the information, Office Supplies Sales is equal to 220,85 dollars

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Which product is ship by the First Class Shipping Mode</strong>
#     </div>
#     </font>

# %%
sns.countplot(x = 'Ship Mode',data = df,hue = 'Category') #plot graph
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %% [markdown]
# ## According to the graph, Office Suppiles has the most shipping orders in every shipping mode

# %% [markdown]
# <font size = 4>
# <div class = 'alert alert-block alert-info'>
#     <strong>Which Sub-Category has the highest Sale and been sent to which State the most?</strong>
#     </div>
#     </font>

# %%
df = pd.read_csv('SampleSuperstore.csv')
df #import data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.groupby(by = 'Sub-Category').sum().sort_values(by = 'Quantity',ascending = False).head() #group data
# Out:
#               Postal Code       Sales  Quantity  Discount      Profit
# Sub-Category
# Binders          83626398  203412.733      5974     567.0  30221.7633
# Paper            76299221   78479.206      5178     102.6  34053.5693
# Furnishings      51880430   91705.164      3563     132.4  13059.1436
# Phones           47897175  330007.054      3289     137.4  44513.7306
# Storage          46248720  223843.608      3158      63.2  21278.8264

# %% [markdown]
# ## According to the table, Binder is the product that has the highest Sales

# %%
df[df['Sub-Category'] == 'Binders'].groupby(by = 'State').sum().sort_values(by = 'Quantity',ascending = False).head()['Quantity']
#Group and sort data
# Out:
# State
# California      1057
# New York         696
# Texas            626
# Washington       365
# Pennsylvania     331
# Name: Quantity, dtype: int64

# %% [markdown]
# ## According to the information, california has the highest order at 1,057 orders
